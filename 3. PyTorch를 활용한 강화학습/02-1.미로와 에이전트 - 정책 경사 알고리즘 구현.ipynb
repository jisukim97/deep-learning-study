# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 미로 구현
# 초기상태

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.gca()

#붉은 벽 그리기
plt.plot([1,1],[0,1], color='red', linewidth=2)
plt.plot([1,2],[2,2], color='red', linewidth=2)
plt.plot([2,2],[2,1], color='red', linewidth=2)
plt.plot([2,3],[1,1], color='red', linewidth=2)

#상태 문자열 표시
plt.text(0.5, 2.5, 'S0', size=14, ha = 'center')
plt.text(1.5, 2.5, 'S1', size=14, ha = 'center')
plt.text(2.5, 2.5, 'S2', size=14, ha = 'center')
plt.text(0.5, 1.5, 'S3', size=14, ha = 'center')
plt.text(1.5, 1.5, 'S4', size=14, ha = 'center')
plt.text(2.5, 1.5, 'S5', size=14, ha = 'center')
plt.text(0.5, 0.5, 'S6', size=14, ha = 'center')
plt.text(1.5, 0.5, 'S7', size=14, ha = 'center')
plt.text(2.5, 0.5, 'S8', size=14, ha = 'center')

# x,y축 범위 설정 및 눈금 제거
ax.set_xlim(0,3)
ax.set_ylim(0,3)
plt.tick_params(axis='both', which='both',bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

#시작점 표시
line, = ax.plot([0.5],[2.5], marker='o', color='g', markersize=55)

# %% [markdown]
# ### 에이전트 구현

# %%
#정책을 결정하는 파라미터의 초깃값 theta_0을 설정
#row - 상태0~7, col - 행동(상,우,하,좌)

theta_0 = np.array([[np.nan, 1, 1, np.nan], #S0일 때 가능한 행동이면 1, 가능하지 않은 방향이면 nan
                     [np.nan, 1, np.nan, 1], #S1
                     [np.nan, np.nan, 1, 1], #S2
                     [1, 1, 1 , np.nan], #S3
                     [np.nan, np.nan, 1, 1], #4
                     [1, np.nan, np.nan, np.nan], #S5
                     [1, np.nan, np.nan, np.nan], #S6
                     [1, 1, np.nan, np.nan] #S7
                    ]) #S8은 목표지점이기 때문에 정책 없음

# %%
#정책 파라미터 theta를 행동 정책 pi로 변환하는 함수

def simple_convert_into_pi_from_theta(theta):
    #단순히 값의 비율을 계산해 확률로 삼는 예시
    [m,n] = theta.shape #theta의 행렬 크기를 구함
    pi = np.zeros((m,n))
    for i in range(0,m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i,:]) #비율계산
    pi = np.nan_to_num(pi) #nan을 0으로 변환
    
    return pi

# %%
#초기 정책 pi_0을 계산
pi_0 = simple_convert_into_pi_from_theta(theta_0)

print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
#한 단계 이동 후의 상태 s_next를 계산하는 함수

def get_next_s(pi, s):
    direction = ['up', 'right', 'down', 'left']
    next_direction = np.random.choice(direction, p=pi[s, :]) #pi [s,:]의 값에 따라 direction 값이 결정됨
    
    if next_direction == 'up':      s_next = s - 3
    elif next_direction == 'right': s_next = s + 1
    elif next_direction == 'down':  s_next = s + 3
    elif next_direction == 'left':  s_next = s - 1
    #next_direction에 따라 현재 상태가 변함
    
    return s_next

# %%
#목표 지점에 이를 때까지 에이전트를 이동시키는 함수

def goal_maze(pi):
    s = 0 #시작 지점
    state_history = [0]
    
    while(1):
        next_s = get_next_s(pi,s)
        state_history.append(next_s)
        
        if next_s == 8: break #목표지점에 이르면 while문 중단
        else: s = next_s #아직 도달 안했으면 s 업데이트
        
    return state_history

# %%
#실제로 경로 이동 히스토리 저장해보기
state_history = goal_maze(pi_0)
# Out:
# 현재 1단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 2단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 3단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 4단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 5단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 6단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 7단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 8단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 9단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 10단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 11단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 12단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 13단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 14단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 15단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 16단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 17단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 18단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 19단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 20단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 21단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 22단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 23단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 24단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 25단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]
# 현재 26단계, pi값은 [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
#결과 출력하기
print('목표 지점에까지 걸린 단계의 수는 '+str(len(state_history)-1)+'단계 입니다.')
print(state_history)
# Out:
# 목표 지점에까지 걸린 단계의 수는 26단계 입니다.
# [0, 1, 2, 5, 2, 1, 0, 1, 0, 1, 0, 1, 0, 3, 6, 3, 0, 1, 0, 1, 0, 3, 0, 3, 4, 7, 8]

# %% [markdown]
# ### 정책경사 알고리즘에 따라 에이전트 이동시키기

# %%
#정책 파라미터 theta를 행동정책 pi로 변환하는 함수에 소프트맥스 함수 사용

def softmax_convert_into_pi_from_theta(theta):
    beta = 1.0
    [m,n] = theta.shape
    pi = np.zeros((m,n))

    exp_theta = np.exp(beta*theta)
    
    for i in range(0,m):
        pi[i,:] = exp_theta[i,:] / np.nansum(exp_theta[i,:])
    
    pi = np.nan_to_num(pi)
    return pi


#초기정책 pi_0 을 계산
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
#행동 a와 한단계 후의 상태 s를 구하는 함수

def get_action_and_next_s(pi, s):
    direction = ['up', 'right', 'down', 'left']
    next_direction = np.random.choice(direction, p=pi[s, :]) #pi [s,:]의 값에 따라 direction 값이 결정됨
    
    if next_direction == 'up':      
        action = 0
        s_next = s - 3
    elif next_direction == 'right': 
        action = 1
        s_next = s + 1
    elif next_direction == 'down':  
        action = 2
        s_next = s + 3
    elif next_direction == 'left':  
        action = 3
        s_next = s - 1
        #next_direction에 따라 현재 상태가 변함
    
    return [action, s_next]

# %%
#목표 지점에 이를 때까지의 상태와 행동의 히스토리를 출력한다

def goal_maze_ret_s_a(pi):
    s = 0 #시작 지점
    s_a_history = [[0, np.nan]] #agent의 행동 및 상태의 히스토리를 기록
    
    while(1):
        [action, next_s] = get_action_and_next_s(pi,s)
        s_a_history[-1][1] = action #현재 상태를 히스토리에 추가
        
        s_a_history.append([next_s, np.nan]) #다음 상태 저장(액션은 아직미정이므로 nan)
        
        if next_s == 8: break #목표지점에 이르면 while문 중단
        else: s = next_s #아직 도달 안했으면 s 업데이트
        
    return s_a_history

# %%
#초기정책으로 미로를 빠져나오기

s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print('걸린 단계 수는',len(s_a_history)-1,"단계 입니다.")
# Out:
# [[0, 2], [3, 2], [6, 0], [3, 0], [0, 1], [1, 1], [2, 3], [1, 3], [0, 2], [3, 1], [4, 2], [7, 1], [8, nan]]
# 걸린 단계 수는 12 단계 입니다.

# %%
#theta를 수정하는 함수 with정책 경사 알고리즘

def update_theta(theta, pi, s_a_history):
    eta = 0.1 #학습률
    T = len(s_a_history) - 1 #목표지점까지 걸린 단계 수
    
    [m,n] = theta.shape
    delta_theta = theta.copy() #theta의 변화값 구할 준비. 포인터로 참조(빠른 계산을 위함)
    
    #delta_theta를 요소 단위로 계산
    for i in range(0,m):
        for j in range(0,n):
            if not(np.isnan(theta[i,j])): #theta가 nan이 아닌 경우
                SA_i = [SA for SA in s_a_history if SA[0] == i] #히스토리에서 상태 i인 것만 모아오는 리스트 컴프리헨션
                SA_ij = [SA for SA in s_a_history if SA == [i,j]] #상태 i에서 행동j를 취한 경우만 모음
                
                N_i = len(SA_i) #상태 i에서 모든 행동을 취한 횟수
                N_ij = len(SA_ij) #상태 i에서 행동 j를 취한 횟수
                
                delta_theta[i,j] = (N_ij - pi[i,j]*N_i) / T
    
    new_theta = theta + eta * delta_theta
    return new_theta


#정책 수정
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.49375033 0.50624967 0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33054408 0.33891184 0.33054408 0.        ]
#  [0.         0.         0.50624967 0.49375033]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.49375033 0.50624967 0.         0.        ]]

# %%
#정책 경사 알고리즘으로 미로 빠져나오기

stop_epsilon = 10**-4 #정책의 변화가 이보다 작아지면 학습을 종료하겠다는 뜻

theta = theta_0
pi = pi_0

is_continue = True
count = 1
while is_continue:
    s_a_history = goal_maze_ret_s_a(pi) #정책 pi를 따라 미로를 탐색한 히스토리를 구함
    new_theta = update_theta(theta, pi, s_a_history) #파라미터 세타를 수정
    new_pi = softmax_convert_into_pi_from_theta(new_theta) #정책 pi를 다시수정
    
    change_amount = np.sum(np.abs(new_pi - pi))
    print(change_amount) #정책 변화 얼만큼됐나
    print(count,'번째 루프, 목표 지점에 이르기까지 걸린 단계 수는',len(s_a_history)-1, '단계입니다.')
    
    if change_amount<stop_epsilon :
        is_continue= False
    else: 
        theta = new_theta
        pi = new_pi
        count += 1
# Out:
# 0.009274861285569314
# 1 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 118 단계입니다.
# 0.012444588682849367
# 2 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 84 단계입니다.
# 0.014011152933675497
# 3 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 46 단계입니다.
# 0.011990538537316908
# 4 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 58 단계입니다.
# 0.011757031172729915
# 5 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 56 단계입니다.
# 0.027139878703052622
# 6 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.011511339598220649
# 7 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 40 단계입니다.
# 0.004643906861422964
# 8 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 74 단계입니다.
# 0.014495580810582998
# 9 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.008009693380118144
# 10 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 90 단계입니다.
# 0.009695242186634756
# 11 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 54 단계입니다.
# 0.008112475430391564
# 12 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 92 단계입니다.
# 0.03957833433084962
# 13 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.008410710154078072
# 14 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 118 단계입니다.
# 0.0185885920090485
# 15 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.02057221205154036
# 16 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.014136098210341064
# 17 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 30 단계입니다.
# 0.010299043278530262
# 18 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 32 단계입니다.
# 0.006030871525229686
# 19 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 98 단계입니다.
# 0.011572693570900072
# 20 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 26 단계입니다.
# 0.03696513186868655
# 21 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.017248437787729776
# 22 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.016738429789353804
# 23 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.008080565504974324
# 24 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 74 단계입니다.
# 0.019850355834685585
# 25 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.03264873217947828
# 26 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.018010083164903712
# 27 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 24 단계입니다.
# 0.010209666533429862
# 28 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.011631953391447736
# 29 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 36 단계입니다.
# 0.006816446769863593
# 30 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 96 단계입니다.
# 0.018851519901153413
# 31 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.012894686019393864
# 32 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 38 단계입니다.
# 0.017115529029965826
# 33 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 38 단계입니다.
# 0.01142566168127973
# 34 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 48 단계입니다.
# 0.020886512816888747
# 35 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.01292264447161695
# 36 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 28 단계입니다.
# 0.02017220307960116
# 37 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.013712549760852732
# 38 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 40 단계입니다.
# 0.0065712025244763494
# 39 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 94 단계입니다.
# 0.012955097704693275
# 40 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 44 단계입니다.
# 0.01570977924183048
# 41 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 28 단계입니다.
# 0.00918907040196254
# 42 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 20 단계입니다.
# 0.005218555309717043
# 43 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 84 단계입니다.
# 0.03181536512560834
# 44 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.027685663178285302
# 45 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.01326255917659741
# 46 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.00951099367980951
# 47 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 112 단계입니다.
# 0.021996694212124135
# 48 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.01417372795244598
# 49 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 34 단계입니다.
# 0.010984835875168575
# 50 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 32 단계입니다.
# 0.008801458201857792
# 51 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 88 단계입니다.
# 0.014144748300801924
# 52 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.032917551707294934
# 53 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.009715088912209735
# 54 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 90 단계입니다.
# 0.011422926283586265
# 55 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.035153631393026685
# 56 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.03198916421000969
# 57 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.005470574741011203
# 58 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 72 단계입니다.
# 0.012215996170658827
# 59 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 40 단계입니다.
# 0.029451706075455275
# 60 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.01706186761634948
# 61 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 36 단계입니다.
# 0.018018269840135936
# 62 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.011857841945606962
# 63 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 54 단계입니다.
# 0.015522821062191439
# 64 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.009681441429247706
# 65 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 40 단계입니다.
# 0.010283525371905688
# 66 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 26 단계입니다.
# 0.009145778307185881
# 67 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.0321901343425659
# 68 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.011322769420313128
# 69 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 32 단계입니다.
# 0.031827438883828774
# 70 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.028668135200001
# 71 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.044384047503238266
# 72 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.007980628415016067
# 73 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 42 단계입니다.
# 0.01749498551662959
# 74 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 22 단계입니다.
# 0.02795817179405985
# 75 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.018557414267176275
# 76 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 56 단계입니다.
# 0.027665278080846234
# 77 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.03542679981322461
# 78 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.024383867337910703
# 79 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.018036414380369792
# 80 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.0184228843079009
# 81 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 22 단계입니다.
# 0.01736966262431655
# 82 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.017158535767641148
# 83 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.00933122057989283
# 84 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 60 단계입니다.
# 0.0159548670799452
# 85 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.017339218422328828
# 86 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 34 단계입니다.
# 0.01915170979926184
# 87 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 20 단계입니다.
# 0.020587148086211926
# 88 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 28 단계입니다.
# 0.012901857330912814
# 89 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.01474078228158926
# 90 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.009396918208678273
# 91 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 42 단계입니다.
# 0.014976829709684503
# 92 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 24 단계입니다.
# 0.018312670836318823
# 93 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 44 단계입니다.
# 0.027188462230284205
# 94 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.01939813961987291
# 95 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.013634297275002372
# 96 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 24 단계입니다.
# 0.014476977393047485
# 97 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 24 단계입니다.
# 0.013919661462341804
# 98 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.029126720443686915
# 99 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.026112619860385933
# 100 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.007975236632995097
# 101 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.012661415939894949
# 102 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.03167212276964665
# 103 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.01915725211953223
# 104 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.009104201222239428
# 105 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 32 단계입니다.
# 0.024621344469028472
# 106 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 24 단계입니다.
# 0.02335553987029887
# 107 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.01142807993283479
# 108 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 32 단계입니다.
# 0.04065223805590734
# 109 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.019894625425683043
# 110 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.023024121614684256
# 111 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.016531827888067674
# 112 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 68 단계입니다.
# 0.012823622043416916
# 113 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 24 단계입니다.
# 0.024730675210515862
# 114 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.011037519256631045
# 115 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.02245011456880036
# 116 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.024562101367938183
# 117 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.016046951080432803
# 118 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.0175681043563225
# 119 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 20 단계입니다.
# 0.014971019805157415
# 120 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 14 단계입니다.
# 0.015842899869933036
# 121 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.009388277000925649
# 122 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 40 단계입니다.
# 0.024572242204142558
# 123 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.015154954926687447
# 124 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.011653731582674576
# 125 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 86 단계입니다.
# 0.012860991400734767
# 126 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.020286964400608454
# 127 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 18 단계입니다.
# 0.019081266235746686
# 128 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.0109596232509796
# 129 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 52 단계입니다.
# 0.022112031771124863
# 130 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.024204914155808777
# 131 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 10 단계입니다.
# 0.01791720877771319
# 132 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 36 단계입니다.
# 0.02158475897812412
# 133 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0.010310234829728593
# 134 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 12 단계입니다.
# 0.012682148229617995
# 135 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 32 단계입니다.
# 0.021685041264153326
# 136 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 8 단계입니다.
# 0.0310417418688122
# 137 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.031067080944071346
# 138 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 6 단계입니다.
# 0.017458779576211392
# 139 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 30 단계입니다.
# 0.017639416532441554
# 140 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 16 단계입니다.
# 0
번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010228036874825042
# 3933 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010212131245602649
# 3934 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010196263277104274
# 3935 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010180432848425416
# 3936 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010164639839217206
# 3937 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010148884129539126
# 3938 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010133165600052785
# 3939 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.0001011748413180958
# 3940 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010101839606440136
# 3941 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010086231905914213
# 3942 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010070660912850186
# 3943 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010055126510203835
# 3944 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010039628581483273
# 3945 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.00010024167010657357
# 3946 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 0.0001000874168208734
# 3947 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.
# 9.993352480706409e-05
# 3948 번째 루프, 목표 지점에 이르기까지 걸린 단계 수는 4 단계입니다.

# %%
#학습이 끝난 정책 pi를 확인
np.set_printoptions(precision=3, suppress=True) #유효 자리수 3, 지수 표시 X
print(pi)
# Out:
# [[0.    0.014 0.986 0.   ]
#  [0.    0.346 0.    0.654]
#  [0.    0.    0.405 0.595]
#  [0.009 0.981 0.01  0.   ]
#  [0.    0.    0.986 0.014]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.019 0.981 0.    0.   ]]

# %% [markdown]
# ### 에이전트의 이동 과정을 시각화

# %%
from matplotlib import animation
from IPython.display import HTML

def init(): #배경 이미지 초기화
    line.set_data([],[])
    return(line,)

def animate(i): #프레임단위로 이미지 생성
    state = s_a_history[i][0] #현재위치
    x = (state%3) + 0.5 #상태의 x좌표: 3으로 나눈 나머지 + 0.5
    y = 2.5 - int(state / 3) #y좌표: 2.5에서 3으로 나눈 몫을 뺌
    line.set_data(x,y)
    return(line,)

#초기화함수와 프레임 단위 이미지 생성 함수를 사용해 애니메이션 생성
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgef075c994df14fb69486b347b1bd7858">
#   <div class="anim-controls">
#     <input id="_anim_slideref075c994df14fb69486b347b1bd7858" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animef075c994df14fb69486b347b1bd7858.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animef075c994df14fb69486b347b1bd7858.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animef075c994df14fb69486b347b1bd7858.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectef075c994df14fb69486b347b1bd7858" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ef075c994df14fb69486b347b1bd7858"
#              checked>
#       <label for="_anim_radio1_ef075c994df14fb69486b347b1bd7858">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ef075c994df14fb69486b347b1bd7858"
#              >
#       <label for="_anim_radio2_ef075c994df14fb69486b347b1bd7858">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ef075c994df14fb69486b347b1bd7858"
#              >
#       <label for="_anim_radio3_ef075c994df14fb69486b347b1bd7858">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgef075c994df14fb69486b347b1bd7858";
#     var slider_id = "_anim_slideref075c994df14fb69486b347b1bd7858";
#     var loop_select_id = "_anim_loop_selectef075c994df14fb69486b347b1bd7858";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAYzUlEQVR4nO3de3CV9b3v8c/KWrmQrGAw4ZKAEM8J\
# EOOQzSW4gyC2hjnG6WEoUuhOREWQnhZ3Z9PC0WJprXbLeFAGmdbp0SOXA+i2HW9A57SHtIUgFy8p\
# WBgxCnvK4erORYKQkMtKfuePAJMgkBBW8nzXyvs1k3H0WXnW19+EN09+ebKWzznnBAAwJ8brAQAA\
# V0agAcAoAg0ARhFoADCKQAOAUQQaAIwi0ABgFIEGAKMINAAYRaABwCgCDQBGEWgAMIpAA4BRBBoA\
# jCLQAGAUgQYAowg0ABhFoAHAKAINAEYRaAAwikADgFEEGgCMItAAYBSBBgCjCDQAGEWgAcAoAg0A\
# RhFoADCKQAOAUQQaAIwi0ABgFIEGAKMINAAYRaABwCgCDQBGEWgAMIpAA4BRBBoAjCLQAGAUgQYA\
# owg0ABhFoAHAqIDXA3RFWlqaMjM
